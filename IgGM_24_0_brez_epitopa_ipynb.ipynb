# %% [markdown]
# <a href="https://colab.research.google.com/github/bkk443/IgGM_mag/blob/main/IgGM_24_0_brez_epitopa_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the library to mount Google Drive
from google.colab import drive

# Mount the Google Drive at /content/drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda --version
# Out:
# conda 23.11.0

# %%
# !git clone https://github.com/TencentAI4S/IgGM.git
# Out:
# fatal: destination path 'IgGM' already exists and is not an empty directory.

# %%
# !cd IgGM

# %%
# !conda env update -n base -f /content/IgGM/environment.yaml
# Out:
# Channels:
#  - pyg
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
# \ Ran pip subprocess with arguments:
# ['/usr/local/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/IgGM/condaenv.zm3298rx.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# ...
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source activate base

# %%
# !conda activate base
# Out:
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local

# %%
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.0.1+cu117.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.0.1+cu117.html
# ...

# %%
#!python /content/IgGM/design.py --fasta /content/IgGM/examples/fasta.files.native/8q94_C_NA_A.fasta --antigen /content/IgGM/examples/pdb.files.native/8q94_C_NA_A.pdb --epitope 41 42 43 44 45 46 49 50 70 71 73 74

# %%
#!python /content/IgGM/design.py --fasta /content/IgGM/examples/TEST/bcII16xCDR3_colab.txt --antigen /content/IgGM/examples/TEST/fold_bcii_cabbcii10_22_model_0.pdb --epitope 33 34 175 176 177 178 179 180 181 182 183 184 185 186 223 224 225 226  --num_samples=16

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/mag/cAbBcII10_BcII10/fold_22_CDR16/bcII16xCDR3_colab.txt --antigen /content/drive/MyDrive/mag/cAbBcII10_BcII10/fold_22_CDR16/fold_bcii_cabbcii10_22_model_0.pdb --output=/content/drive/MyDrive/mag/cAbBcII10_BcII10/fold_22_CDR16/Outputs --epitope 33 34 175 176 177 178 179 180 181 182 183 184 185 186 223 224 225 226  --num_samples=16

# %% [markdown]
# Primer komand
# open "C:\\Users\\Bor\\OneDrive - Univerza v Ljubljani\\5. letnik\\Magisterij\\Nanobody design\\In silico dizajn\\AF3\\BcII-cAbBcII10\\top5_modelov\\fold_bcii_cabbcii10_24_model_0.cif"
#
# ui tool show "Show Sequence Viewer"
# sequence chain /A
# sequence chain /B
# select /A:102-117  #to je CDR3
# contacts sel distanceOnly 5.0 intraMol false select true log true
#
#
# **fold_bcii_cabbcii10_24_model_0**.cif
# 34,35, 176-187, 225-227
# --epitope 33 34 175 176 177 178 179 180 181 182 183 184 185 186 224 225 226

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/bcII16xCDR3_colab220.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/24_model_0.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/Outputs22_1 --epitope 33 34 175 176 177 178 179 180 181 182 183 184 185 186 224 225 226 --num_samples=48

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_22_model_2_CDR3/bcII16xCDR3_colab22_2.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_22_model_2_CDR3/22_model_2_CDR3.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_22_model_2_CDR3/Outputs1 --epitope 33 175 176 177 178 179 180 181 182 183 184 185 186 224 225 226 --num_samples=96

# %% [markdown]
# Brez epitpša

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_12_model_0_CDR3/bcII16xCDR3_colab12_0.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_12_model_0_CDR3/12_model_0_CDR3.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_12_model_0_CDR3/Outputs --num_samples=96

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_0/bcII16xCDR3_colab19_0.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_0/19_model_0.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_0/Outputs --num_samples=96

# %% [markdown]
# brez --epitope

# %%
#!python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_1/bcII16xCDR3_colab12_0.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_1/19_model_1.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_19_model_1/Outputs --num_samples=96
# Out:
# [2024-11-25 09:39:15,475] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  NVIDIA Inference is only supported on Ampere and newer architectures
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.0
#  [WARNING]  using untested triton version (2.0.0), only 1.0.0 is known to be compatible
# WARNING:root:using DS4Sci_EvoformerAttention
# Loading ESM PPI 650m AB model
# Loading Antibody Design Model
# Download IGSO3Buffer for accelerating SO3 operations
# ...

# %% [markdown]
# 24_0 brez epitopa 96

# %%
# !python /content/IgGM/design.py --fasta /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/bcII16xCDR3_colab220.txt --antigen /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/24_model_0.pdb --output /content/drive/MyDrive/Colab_Notebooks/mag/fold_bcii_cabbcii10_24_model_0/Output_brezepitopa --num_samples=96
# Out:
# [2024-11-25 11:27:36,882] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  NVIDIA Inference is only supported on Ampere and newer architectures
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.0
#  [WARNING]  using untested triton version (2.0.0), only 1.0.0 is known to be compatible
# WARNING:root:using DS4Sci_EvoformerAttention
# Loading ESM PPI 650m AB model
# Loading Antibody Design Model
# Download IGSO3Buffer for accelerating SO3 operations
# ...

# %%
###
import argparse
import os
import sys

import torch
import tqdm


sys.path.append('.')

from IgGM.deploy import AbDesigner
from IgGM.utils import setup
from IgGM.protein.parser import parse_fasta, PdbParser
from IgGM.model.pretrain import esm_ppi_650m_ab, antibody_design_trunk, IGSO3Buffer_trunk


aa_seq, atom_cord, atom_cmsk, _, _ = PdbParser.load("/content/IgGM/examples/pdb.files.native/8q94_C_NA_A.pdb", chain_id="A")
print(aa_seq[i])
print(f"Sequence length: {len(aa_seq)}")  # Should print 227
